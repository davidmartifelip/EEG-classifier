# %%
# llegir les dades
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
from visualitzacions import *
# Out:
# /Users/davidmarti/Library/CloudStorage/OneDrive-UAB/4t curs/TFG/dades/visualitzacions.py:17: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   channel_info = np.genfromtxt("channel_info.csv", delimiter=",", dtype=None)

# %%
plot_channels(all, 0)

# %%
plot_correlation_matrix(mor_avg, 4)

# %%
plot_subject(mor_avg, 0)

# %%
plot_global(mor_avg, data_label="mor")

# %%
plot_global(str_avg)

# %% [markdown]
# Visualització dels canals frontals, respecte esquerra i dreta

# %%
canals_frontals = ['AF3', 'F1', 'F3', 'FC5', 'FC3', 'FC1', 'AF4', 'F2', 'F4', 'FC6', 'FC4', 'FC2', 'Fz']
canals_esquerra = ['CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'CPz', 'Pz', 'C1', 'C3', 'C5', 'Cz']
canals_dreta = ['CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'C2', 'C4', 'C6']

topoplot( [canals_dreta, canals_esquerra, canals_frontals])

# %%
plot_global(mor_avg, channels = canals_frontals, data_label = "Mora - canals frontals")
#plot_global(mor_avg, channels = canals_esquerra, data_label = "Mora - canals esquerra")
#plot_global(mor_avg, channels = canals_dreta, data_label = "Mora - canals dreta")

# %%
plot_channels(str_avg, channel_list=canals_frontals, data_label="Stress - canals frontals")
plot_channels(str_avg, channel_list=canals_esquerra, data_label="Stress - canals esquerra")
plot_channels(str_avg, channel_list=canals_dreta, data_label="Stress - canals dreta")
plot_channels(syl_avg, channel_list=canals_frontals, data_label="Syllable - canals frontals")
plot_channels(syl_avg, channel_list=canals_esquerra, data_label="Syllable - canals esquerra")
plot_channels(syl_avg, channel_list=canals_dreta, data_label="Syllable - canals dreta")
plot_channels(mor_avg, channel_list=canals_frontals, data_label="Mora - canals frontals")
plot_channels(mor_avg, channel_list=canals_esquerra, data_label="Mora - canals esquerra")
plot_channels(mor_avg, channel_list=canals_dreta, data_label="Mora - canals dreta")

# %%
plot_channel(all_avg, channel_dict['FC1'])
print()
plot_channel(all_avg, channel_dict['P1'])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_subject([5], 0)
#
# File ~/Library/CloudStorage/OneDrive-UAB/4t curs/TFG/dades/visualitzacions.py:119, in plot_subject(set, subject_idx, channel_info)
#     117 time_resolution = 500  # 50 ms
#     118 time_ticks = np.arange(time_start, time_end + time_resolution, time_resolution)
# --> 119 time_tick_positions = np.linspace(0, set.shape[2] - 1, len(time_ticks))
#     121 plt.imshow(set[subject_idx, :, :], aspect='auto')
#     122 plt.xlabel(time_ms_label)
#
# AttributeError: 'list' object has no attribute 'shape'
